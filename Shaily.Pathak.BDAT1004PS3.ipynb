# %% [markdown]
# Question 1
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and
# materials.
# Occupations

# %%
import numpy as np
import pandas as pd
users = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', delimiter='|')

users.head()
users[['occupation','age']].groupby('occupation').mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users.head()
df = users[['gender','occupation']]
male = df.loc[df['gender'] == 'M']
total = df.groupby('occupation').count()
male = male.groupby('occupation').count()
ratio = male / total
ratio.sort_values(by='gender', ascending=False)
# Out:
#                  gender
# occupation
# doctor         1.000000
# engineer       0.970149
# technician     0.962963
# retired        0.928571
# programmer     0.909091
# executive      0.906250
# scientist      0.903226
# entertainment  0.888889
# lawyer         0.833333
# salesman       0.750000
# educator       0.726316
# student        0.693878
# other          0.657143
# marketing      0.615385
# writer         0.577778
# none           0.555556
# administrator  0.544304
# artist         0.535714
# librarian      0.431373
# healthcare     0.312500
# homemaker      0.142857

# %% [markdown]
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.head()
df = users[['age','occupation']]
df.groupby('occupation').min()
df.groupby('occupation').max()
# Out:
#                age
# occupation
# administrator   70
# artist          48
# doctor          64
# educator        63
# engineer        70
# entertainment   50
# executive       69
# healthcare      62
# homemaker       50
# lawyer          53
# librarian       69
# marketing       55
# none            55
# other           64
# programmer      63
# retired         73
# salesman        66
# scientist       55
# student         42
# technician      55
# writer          60

# %% [markdown]
# Step 7. For each combination of occupation and sex, calculate the mean age

# %%
users.head()
df = users[['age','occupation','gender']]
df.groupby(['occupation','gender']).min()
df.groupby(['occupation','gender']).max()
# Out:
#                       age
# occupation    gender
# administrator F        62
#               M        70
# artist        F        48
#               M        45
# doctor        M        64
# educator      F        51
#               M        63
# engineer      F        36
#               M        70
# entertainment F        38
#               M        50
# executive     F        49
#               M        69
# healthcare    F        53
#               M        62
# homemaker     F        50
#               M        23
# lawyer        F        51
#               M        53
# librarian     F        59
#               M        69
# marketing     F        50
#               M        55
# none          F        55
#               M        33
# other         F        55
#               M        64
# programmer    F        38
#               M        63
# retired       F        70
#               M        73
# salesman      F        33
#               M        66
# ...

# %% [markdown]
# Step 8. For each occupation present the percentage of women and men

# %%
gender_occupation = users.groupby('gender')['occupation'].value_counts()
male_sex_ratio = gender_occupation['M']/(gender_occupation['M'] + gender_occupation['F'])*100
female_sex_ratio = gender_occupation['F']/(gender_occupation['M'] + gender_occupation['F'])*100
print(male_sex_ratio, female_sex_ratio)
# Out:
# occupation
# administrator    54.430380
# artist           53.571429
# doctor                 NaN
# educator         72.631579
# engineer         97.014925
# entertainment    88.888889
# executive        90.625000
# healthcare       31.250000
# homemaker        14.285714
# lawyer           83.333333
# librarian        43.137255
# marketing        61.538462
# none             55.555556
# other            65.714286
# programmer       90.909091
# retired          92.857143
# salesman         75.000000
# scientist        90.322581
# student          69.387755
# technician       96.296296
# writer           57.777778
# Name: occupation, dtype: float64 occupation
# administrator    45.569620
# artist           46.428571
# doctor                 NaN
# educator         27.368421
# engineer          2.985075
# entertainment    11.111111
# executive         9.375000
# healthcare       68.750000
# homemaker        85.714286
# lawyer           16.666667
# librarian        56.862745
# ...

# %% [markdown]
# Question 2
# Euro Teams
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column

# %%
import pandas as pd

euro12 = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
euro12.head()
df = euro12[['Goals']]
df
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# Step 5. How many team participated in the Euro2012?

# %%
totalteam = euro12[['Team']].nunique()
totalteam
# Out:
# Team    16
# dtype: int64

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
print("The number of columns in the dataframe is: ", len(euro12.columns))
# Out:
# The number of columns in the dataframe is:  35

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them
# to a dataframe called discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline = discipline.sort_values(by=['Red Cards', 'Yellow Cards'])
print(discipline)
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# Step 10. Filter teams that scored more than 6 goalsStep

# %%
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# 11. Select the teams that start with G

# %%
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# Step 12. Select the first 7 columns

# %%
euro12.iloc[:, :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 13. Select all columns except the last 3

# %%
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
df = euro12[(euro12.Team == "England") | (euro12.Team == "Italy") | (euro12.Team == "Russia")]
df[["Team","Shooting Accuracy"]]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# Question 3
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000

# %%
import pandas as pd
import random

Series_A = pd.Series(random.randint(1, 4) for _ in range(100))
Series_B = pd.Series(random.randint(1, 2) for _ in range(100))
Series_C = pd.Series(random.randint(10000, 30000) for _ in range(100))

# %% [markdown]
# Step 3. Create a DataFrame by joinning the Series by column

# %%
df = pd.concat([Series_A, Series_B, Series_C], axis = 1)
df
# Out:
#     0  1      2
# 0   3  2  16378
# 1   3  2  25965
# 2   3  2  14975
# 3   2  1  29327
# 4   1  2  12545
# .. .. ..    ...
# 95  3  2  14270
# 96  1  2  11928
# 97  2  1  27219
# 98  1  1  17955
# 99  4  1  14247
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns = ["bedrs", "bathrs", "price_sqr_meter"]
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       2            16378
# 1       3       2            25965
# 2       3       2            14975
# 3       2       1            29327
# 4       1       2            12545
# ..    ...     ...              ...
# 95      3       2            14270
# 96      1       2            11928
# 97      2       1            27219
# 98      1       1            17955
# 99      4       1            14247
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'

# %%
dataframe = pd.concat([Series_A, Series_B, Series_C])
dataframe
# Out:
# 0         4
# 1         2
# 2         2
# 3         1
# 4         1
#       ...
# 95    25737
# 96    26125
# 97    24355
# 98    17047
# 99    18323
# Length: 300, dtype: int64

# %% [markdown]
# Step 6. Ops it seems it is going only until index 99. Is it true?
#
# Yes, its true

# %% [markdown]
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
dataframe.reset_index(drop=True)
# Out:
# 0          4
# 1          2
# 2          2
# 3          1
# 4          1
#        ...
# 295    25737
# 296    26125
# 297    24355
# 298    17047
# 299    18323
# Length: 300, dtype: int64

# %% [markdown]
# Question 4
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:

# %%
import pandas as pd
import datetime

wind = pd.read_csv('wind.txt', delimiter='\s+')
wind
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
wind.rename(columns={'Yr':'Year','Mo':"Month","Dy":"Day"}, inplace=True)
wind
# Out:
#       Year  Month  Day    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0       61      1    1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1       61      1    2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2       61      1    3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3       61      1    4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4       61      1    5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...    ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 6569    78     12   27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570    78     12   28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571    78     12   29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572    78     12   30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573    78     12   31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# 0     10.25  10.83  12.58  18.50  15.04
# ...

# %%
wind['Year'] += 1900
wind
# Out:
#       Year  Month  Day    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0     1961      1    1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1     1961      1    2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2     1961      1    3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3     1961      1    4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4     1961      1    5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...    ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978     12   27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570  1978     12   28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571  1978     12   29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572  1978     12   30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573  1978     12   31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# 0     10.25  10.83  12.58  18.50  15.04
# ...

# %%
wind.index = pd.to_datetime(pd.concat([wind['Year'], wind['Month'], wind['Day']], axis=1))
wind.drop(['Year','Month','Day'], axis=1, inplace=True)
wind
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# 1961-01-01  12.58  18.50  15.04
# ...

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %%
wind.isnull().sum().sum()
# Out:
# 31

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times.

# %%
wind.notnull().sum().sum()
# Out:
# 78857

# %%
wind.mean().mean()
# Out:
# 10.227982360836924

# %%
wind[:24]
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# 1961-01-06  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42   7.17
# 1961-01-07  13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29   7.58
# 1961-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25
# 1961-01-09  12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13   7.79
# 1961-01-10  13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79   8.54
# 1961-01-11  10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33   5.71
# 1961-01-12  19.75  12.08  18.50  10.54  10.29   9.46  15.54  11.50  10.37
# ...

# %%
loc_stats = pd.concat([wind.mean(), wind.min(), wind.max(), wind.std()], axis=1)
loc_stats.rename(columns={0:'Mean',1:'Min',2:'Max',3:'Std'}, inplace=True)
loc_stats
# Out:
#           Mean   Min    Max       Std
# RPT  12.362987  0.67  35.80  5.618413
# VAL  10.644314  0.21  33.37  5.267356
# ROS  11.660526  1.50  33.84  5.008450
# KIL   6.306468  0.00  28.46  3.605811
# SHA  10.455834  0.13  37.54  4.936125
# BIR   7.092254  0.00  26.16  3.968683
# DUB   9.797343  0.00  30.37  4.977555
# CLA   8.495053  0.00  31.08  4.499449
# MUL   8.493590  0.00  25.88  4.166872
# CLO   8.707332  0.04  28.21  4.503954
# BEL  13.121007  0.13  42.38  5.835037
# MAL  15.599079  0.67  42.54  6.699794

# %%
day_stats = pd.concat([wind.mean(axis=1), wind.min(axis=1), wind.max(axis=1), wind.std(axis=1)], axis=1)
day_stats.rename(columns={0:'Mean',1:'Min',2:'Max',3:'Std'}, inplace=True)
day_stats
# Out:
#                  Mean   Min    Max       Std
# 1961-01-01  13.018182  9.29  18.50  2.808875
# 1961-01-02  11.336364  6.50  17.54  3.188994
# 1961-01-03  11.641818  6.17  18.50  3.681912
# 1961-01-04   6.619167  1.79  11.75  3.198126
# 1961-01-05  10.630000  6.17  13.33  2.445356
# ...               ...   ...    ...       ...
# 1978-12-27  16.708333  8.08  40.08  7.868076
# 1978-12-28  15.150000  5.00  41.46  9.687857
# 1978-12-29  14.890000  8.71  29.58  5.756836
# 1978-12-30  15.367500  9.13  28.79  5.540437
# 1978-12-31  15.402500  9.59  27.29  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# Step 13. Downsample the record to a monthly frequency for each location.

# %%
jan = wind[wind.index.month == 1]
jan.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
yearly = wind.resample('Y').ffill()
yearly
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 1961-12-31   9.87   7.83   7.67   3.75   5.66   3.50  10.04   3.08   5.04
# 1962-12-31  22.67  16.88  28.67  14.12  19.75  17.08  27.79  25.21  19.83
# 1963-12-31  13.88  14.42  12.12   9.25  14.33  10.67  18.29  11.96  12.04
# 1964-12-31  16.33  19.25  13.37  10.08  17.04  12.54  19.83  13.79  12.67
# 1965-12-31  13.62  13.88  12.29   6.08  12.33   7.41   9.59  10.21   7.46
# 1966-12-31  13.00  11.46  10.13   6.34  11.87   7.50  13.50   8.46  11.00
# 1967-12-31  16.88  13.75  11.34   9.08  13.54   7.71  11.75  11.83  11.83
# 1968-12-31   9.13   2.13   7.38   2.50   4.04   0.50   6.83   2.54   3.54
# 1969-12-31  14.42  13.83  27.71   7.08  12.08  10.00  14.58  11.00  12.54
# 1970-12-31   8.38   0.37   9.59   2.62   1.75   0.08   4.83   2.13   2.54
# 1971-12-31  14.88  10.50  26.08   8.46  13.50  10.04  21.04  10.25  13.54
# 1972-12-31  13.83  14.46  15.87   9.75   8.71  11.00  10.67  11.54  11.50
# ...

# %%
monthly = wind.resample('M').ffill()
monthly
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 1961-01-31  24.21  19.55  16.71  11.96  14.42  10.46  14.88   8.21  10.50
# 1961-02-28  12.92  12.75    NaN   8.92  16.13  12.29  14.75  14.46  13.96
# 1961-03-31   8.96   8.04   9.13   8.50  10.75   9.54  11.92   9.59  11.25
# 1961-04-30  11.67  11.00   9.54   5.54   9.42   5.79   5.09   8.25   6.96
# 1961-05-31   7.00   9.79  12.25   4.83   8.25   5.37   6.58   9.29   6.58
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-08-31  11.54   5.54   7.41   4.67   7.62   6.17   8.87   5.25   7.83
# 1978-09-30  26.75  15.63  16.54  13.37  17.58  13.13  16.92  13.79  13.46
# 1978-10-31   8.58   4.29  10.79   4.29   4.08   2.71   4.63   1.04   3.67
# 1978-11-30  15.34   4.54  14.75   3.50   4.54   4.96   7.50   2.42   4.96
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# 1961-01-31   9.96  12.42  13.92
# ...

# %%
weekly = wind.resample('W').ffill()
weekly
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25
# 1961-01-15  12.04   9.67  11.75   2.37   7.38   3.13   2.50   6.83   4.75
# 1961-01-22   9.59   5.88   9.92   2.17   6.87   5.50   9.38   7.04   6.34
# 1961-01-29    NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-03  21.21  21.34  17.75  11.58  16.75  14.46  17.46  15.29  15.79
# 1978-12-10  24.92  22.54  16.54  14.62  15.59  13.00  13.21  14.12  16.21
# 1978-12-17   9.87   3.21   8.04   2.21   3.04   0.54   2.46   1.46   1.29
# 1978-12-24   8.67   5.63  12.12   4.79   5.09   5.91  12.25   9.25  10.83
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# 1961-01-01  12.58  18.50  15.04
# ...

# %%
weekly_stats = weekly[:52]
weekly_stats = pd.concat([weekly_stats.mean(), weekly_stats.max(), weekly_stats.mean(), weekly_stats.std()], axis=1)
weekly_stats.rename(columns={0:'Mean',1:'Max',2:'Mean',3:'Std'},inplace=True)
weekly_stats
# Out:
#           Mean    Max       Mean       Std
# RPT  12.140000  25.80  12.140000  5.360926
# VAL  10.626538  23.91  10.626538  4.782553
# ROS  11.261731  22.42  11.261731  4.714533
# KIL   6.862549  17.54   6.862549  3.743912
# SHA  11.242745  24.08  11.242745  4.770084
# BIR   7.946346  19.70   7.946346  3.906412
# DUB   9.912353  22.00   9.912353  4.695142
# CLA   9.305385  20.25   9.305385  4.022109
# MUL   8.823077  21.46   8.823077  4.181664
# CLO   9.939615  20.04   9.939615  4.077699
# BEL  14.015192  29.63  14.015192  5.885208
# MAL  13.282692  26.58  13.282692  5.785169

# %% [markdown]
# Question 5
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipotle = pd.read_csv(url, sep='\t')
chipotle[:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipotle.index.size
# Out:
# 4622

# %%
chipotle.columns.size
# Out:
# 5

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
chipotle.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
print(chipotle.index)
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
most_ordered = chipotle.sort_values('quantity', ascending=False).head(1)
most_ordered
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %%
most_ordered['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
most_ordered['choice_description']
# Out:
# 3598    NaN
# Name: choice_description, dtype: object

# %%
chipotle['quantity'].sum()
# Out:
# 4972

# %%
item_price = chipotle['item_price'].apply(lambda x: x.replace('$', '')).astype(float)
chipotle['item_price'] = item_price
item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
(chipotle['item_price'] * chipotle['quantity']).sum()
# Out:
# 39237.02

# %%
chipotle['order_id'].count()
# Out:
# 4622

# %%
average = (chipotle['item_price'] * chipotle['quantity']).mean()
average
# Out:
# 8.489186499350943

# %%
chipotle['item_name'].unique().size
# Out:
# 50

# %% [markdown]
# Question 6
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
us = pd.read_csv('us-marriages-divorces-1867-2014.csv')
us.index = us['Year']
mrg_per_capita = us['Marriages_per_1000'] / 1000
div_per_capita = us['Divorces_per_1000'] / 1000

df = pd.concat([mrg_per_capita, div_per_capita], axis=1).rename(columns={'Marriages_per_1000':'Marriages_per_capita','Divorces_per_1000':'Divorces_per_capita'})
mask = (df.index >= 1867) & (df.index <= 2014)
df.loc[mask].plot(xlabel='Year', ylabel='Marriages/Divorces per capita')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Marriages/Divorces per capita'>

# %% [markdown]
# Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
mask = (df.index == 1900) | (df.index == 1950) | (df.index == 2000)
df.loc[mask].plot.bar(xlabel='Year', ylabel='Marriages/Divorces per capita')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Marriages/Divorces per capita'>

# %% [markdown]
# Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
actor_kills_data = pd.read_csv('actor_kill_counts.csv')
kills = actor_kills_data.sort_values(by=['Count'])


actor_names = kills['Actor'].values
kill_counts = kills['Count'].values


plt.bar(actor_names, kill_counts, label=actor_names)
plt.xticks(rotation='vertical')
plt.xlabel("Actor name")
plt.ylabel("Total no of kills")
# Out:
# Text(0, 0.5, 'Total no of kills')

# %% [markdown]
# Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
roman = pd.read_csv('roman-emperor-reigns.csv')
mask = roman['Cause_of_Death'].str.contains('ssassin')
assassinated = roman.loc[mask].set_index('Emperor').drop(['Length_of_Reign'], axis=1)
assassinated.groupby('Cause_of_Death').size().plot.pie(ylabel='Number of Emperors')
# Out:
# <AxesSubplot:ylabel='Number of Emperors'>

# %% [markdown]
# Question 10
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as plt
# %matplotlib inline


arcade_revenue_data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
arcade_revenue = arcade_revenue_data['Total Arcade Revenue (billions)'].values
cs_doctorates = arcade_revenue_data['Computer Science Doctorates Awarded (US)'].values


fig, p = plt.subplots()

colors = cm.rainbow(np.linspace(0, 1, len(arcade_revenue_data['Year'])))

for i in range(len(arcade_revenue_data['Year'])):
    p.scatter(arcade_revenue[i], cs_doctorates[i],color=colors[i])

p.set_xlabel('Total Revenue (billions)')
p.set_ylabel('Computer Science Doctorates Awarded (US)')
# Out:
# Text(0, 0.5, 'Computer Science Doctorates Awarded (US)')
